# %%
#Purpose: plot when our cohort typically arrives on campus  

import pandas as pd

#Read the file and display it as a dataframe and make the original headers row 1 
class_data_df = pd.read_csv('data.csv', header = None )
class_data_df
# Out:
#           0         1        2        3        4        5
# 0   8:56 AM   9:00 AM  7:45 AM  7:45 AM  8:05 AM  7:45 AM
# 1   8:40 AM   8:40 AM  8:30 AM  8:30 AM  8:45 AM  8:20 AM
# 2   8:45 AM   8:20 AM  8:05 AM  8:00 AM  8:05 AM  8:00 AM
# 3   8:40 AM   8:40 AM  8:40 AM  8:25 AM  8:40 AM  8:40 AM
# 4   8:55 AM   8:50 AM  8:55 AM  8:10 AM  8:15 AM  8:05 AM
# 5   8:45 AM   8:45 AM  8:45 AM  8:40 AM  8:30 AM  8:40 AM
# 6   8:45 AM   8:54 AM  8:38 AM  8:40 AM  8:32 AM  8:41 AM
# 7    absent  11:00 AM  8:35 AM  8:15 AM  8:10 AM  8:10 AM
# 8   8:39 AM   8:13 AM  8:15 AM  8:12 AM  8:10 AM  8:00 AM
# 9   9:00 AM   8:50 AM  8:50 AM  8:50 AM  8:40 AM  8:45 AM
# 10  8:40 AM   8:50 AM  8:40 AM  8:34 AM  8:20 AM  8:30 AM
# 11  8:15 AM   8:30 AM  8:13 AM  8:30 AM  7:45 AM  8:40 AM
# 12  8:45 AM   8:55 AM  8:45 AM  8:45 AM  8:00 AM  8:45 AM
# 13  8:45 AM   8:45 AM  8:05 AM  8:00 AM  8:00 AM  8:00 AM
# 14  8:45 AM   8:45 AM  9:00 AM  9:00 AM  8:50 AM  9:00 AM
# ...

# %%
#Reame the headers
class_data_df.columns = ["Day_1","Day_2","Day_3","Day_4","Day_5","Day_6"] 
class_data_df
# Out:
#       Day_1     Day_2    Day_3    Day_4    Day_5    Day_6
# 0   8:56 AM   9:00 AM  7:45 AM  7:45 AM  8:05 AM  7:45 AM
# 1   8:40 AM   8:40 AM  8:30 AM  8:30 AM  8:45 AM  8:20 AM
# 2   8:45 AM   8:20 AM  8:05 AM  8:00 AM  8:05 AM  8:00 AM
# 3   8:40 AM   8:40 AM  8:40 AM  8:25 AM  8:40 AM  8:40 AM
# 4   8:55 AM   8:50 AM  8:55 AM  8:10 AM  8:15 AM  8:05 AM
# 5   8:45 AM   8:45 AM  8:45 AM  8:40 AM  8:30 AM  8:40 AM
# 6   8:45 AM   8:54 AM  8:38 AM  8:40 AM  8:32 AM  8:41 AM
# 7    absent  11:00 AM  8:35 AM  8:15 AM  8:10 AM  8:10 AM
# 8   8:39 AM   8:13 AM  8:15 AM  8:12 AM  8:10 AM  8:00 AM
# 9   9:00 AM   8:50 AM  8:50 AM  8:50 AM  8:40 AM  8:45 AM
# 10  8:40 AM   8:50 AM  8:40 AM  8:34 AM  8:20 AM  8:30 AM
# 11  8:15 AM   8:30 AM  8:13 AM  8:30 AM  7:45 AM  8:40 AM
# 12  8:45 AM   8:55 AM  8:45 AM  8:45 AM  8:00 AM  8:45 AM
# 13  8:45 AM   8:45 AM  8:05 AM  8:00 AM  8:00 AM  8:00 AM
# 14  8:45 AM   8:45 AM  9:00 AM  9:00 AM  8:50 AM  9:00 AM
# ...

# %%
class_data_df.loc[7,'Day_1'] = 0
class_data_df.loc[7,'Day_1']
# Out:
# 0

# %%
# skip this cell 
# class_data_df = class_data_df.loc[class_data_df['Day_1']!="absent"]
# class_data_df.head()

# %%
class_data_df['Day_1']
type(class_data_df['Day_1'])

#convert time into an integer 

time_string = str(class_data_df['Day_1'])
time_list = time_string.split()
def by_size(words, size):
    return [word for word in words if len(word) == size]

only_time_day1 = by_size(time_list, 4)

# %%
class_data_df['Day_2']
type(class_data_df['Day_2'])

#convert time into an integer 

time_string = str(class_data_df['Day_2'])
time_list = time_string.split()
def by_size(words, size):
    return [word for word in words if len(word) == size]

only_time_day2 = by_size(time_list, 4)

# %%
class_data_df['Day_3']
type(class_data_df['Day_3'])

#convert time into an integer 

time_string = str(class_data_df['Day_3'])
time_list = time_string.split()
def by_size(words, size):
    return [word for word in words if len(word) == size]

only_time_day3 = by_size(time_list, 4)

# %%
class_data_df['Day_4']
type(class_data_df['Day_4'])

#convert time into an integer 

time_string = str(class_data_df['Day_4'])
time_list = time_string.split()
def by_size(words, size):
    return [word for word in words if len(word) == size]

only_time_day4 = by_size(time_list, 4)

# %%
class_data_df['Day_5']
type(class_data_df['Day_5'])

#convert time into an integer 

time_string = str(class_data_df['Day_5'])
time_list = time_string.split()
def by_size(words, size):
    return [word for word in words if len(word) == size]

only_time_day5 = by_size(time_list, 4)

# %%
class_data_df['Day_6']
type(class_data_df['Day_6'])

#convert time into an integer 

time_string = str(class_data_df['Day_6'])
time_list = time_string.split()
def by_size(words, size):
    return [word for word in words if len(word) == size]

only_time_day6 = by_size(time_list, 4)

# %%
# This is wrong ignore 
# def change_time(time):
#     time = str(time)
#     return time[:5]
#class_data_df = class_data_df.loc[class_data_df['Day_1'].apply(change_time),:]

#pd.timestamp
#pd.Timestamp(year=2017, month=1, day=1, hour=12)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline

# #Create a bar chart of the average arrival times 
# fig, ax = plt.subplots(figsize = (20,20))

# # Label plot
# ax.set_title('Class Arrival Times')

# ax.set_xlabel('Days')
# ax.set_ylabel('Average Arrival Time')

# # Generate data
# x = (class_data_df.columns)
# y = (class_data_df['Day_1'].mean(),class_data_df['Day_2'].mean(),class_data_df['Day_3'].mean(),
#      class_data_df['Day_4'].mean(),class_data_df['Day_5'].mean(),class_data_df['Day_6'].mean())

# # Plot
# ax.hist(x, y, color="blue")

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate data on commute times.
size, scale = 1000, 10

x = only_time_day1

plt.hist(x, bins=4, rwidth=0.9,
                   color='blue')
plt.title('Average Cohort Arrival Times Day 1')
plt.xlabel('Day')
plt.ylabel('Average Arrival Time')
# Out:
# Text(0, 0.5, 'Average Arrival Time')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate data on commute times.
size, scale = 1000, 10

x = only_time_day2

plt.hist(x, bins=4, rwidth=0.9,
                   color='blue')
plt.title('Average Cohort Arrival Times Day 2')
plt.xlabel('Day')
plt.ylabel('Average Arrival Time')
# Out:
# Text(0, 0.5, 'Average Arrival Time')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate data on commute times.
size, scale = 1000, 10

x = only_time_day3

plt.hist(x, bins=4, rwidth=0.9,
                   color='blue')
plt.title('Average Cohort Arrival Times Day 3')
plt.xlabel('Day')
plt.ylabel('Average Arrival Time')
# Out:
# Text(0, 0.5, 'Average Arrival Time')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate data on commute times.
size, scale = 1000, 10

x = only_time_day4

plt.hist(x, bins=4, rwidth=0.9,
                   color='blue')
plt.title('Average Cohort Arrival Times Day 4')
plt.xlabel('Day')
plt.ylabel('Average Arrival Time')
# Out:
# Text(0, 0.5, 'Average Arrival Time')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate data on commute times.
size, scale = 1000, 10

x = only_time_day5

plt.hist(x, bins=4, rwidth=0.9,
                   color='blue')
plt.title('Average Cohort Arrival Times Day 5')
plt.xlabel('Day')
plt.ylabel('Average Arrival Time')
# Out:
# Text(0, 0.5, 'Average Arrival Time')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate data on commute times.
size, scale = 1000, 10

x = only_time_day6

plt.hist(x, bins=4, rwidth=0.9,
                   color='blue')
plt.title('Average Cohort Arrival Times Day 6')
plt.xlabel('Day')
plt.ylabel('Average Arrival Time')
# Out:
# Text(0, 0.5, 'Average Arrival Time')
